# %% [markdown]
# # US - Baby Names

# %% [markdown]
# ### Introduction:
#
# We are going to use a subset of [US Baby Names](https://www.kaggle.com/kaggle/us-baby-names) from Kaggle.
# In the file it will be names from 2004 until 2014
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called baby_names.

# %%
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv"
baby_names = pd.read_csv(url)
baby_names
# Out:
#          Unnamed: 0       Id     Name  Year Gender State  Count
# 0             11349    11350     Emma  2004      F    AK     62
# 1             11350    11351  Madison  2004      F    AK     48
# 2             11351    11352   Hannah  2004      F    AK     46
# 3             11352    11353    Grace  2004      F    AK     44
# 4             11353    11354    Emily  2004      F    AK     41
# ...             ...      ...      ...   ...    ...   ...    ...
# 1016390     5647421  5647422     Seth  2014      M    WY      5
# 1016391     5647422  5647423  Spencer  2014      M    WY      5
# 1016392     5647423  5647424     Tyce  2014      M    WY      5
# 1016393     5647424  5647425   Victor  2014      M    WY      5
# 1016394     5647425  5647426   Waylon  2014      M    WY      5
#
# [1016395 rows x 7 columns]

# %% [markdown]
# ### Step 5. Delete the column 'Unnamed: 0' and 'Id'

# %%
baby_names.rename(columns={"Unnamed: 0" : "Id"}, inplace=True)

# %% [markdown]
# ### Step 6. Is there more male or female names in the dataset?

# %%
# deletes Unnamed: 0
del baby_names['Unnamed: 0']

# deletes Unnamed: 0
del baby_names['Id']

baby_names.head()
# Out:
#       Name  Year Gender State  Count
# 0     Emma  2004      F    AK     62
# 1  Madison  2004      F    AK     48
# 2   Hannah  2004      F    AK     46
# 3    Grace  2004      F    AK     44
# 4    Emily  2004      F    AK     41

# %% [markdown]
# ### Step 7. Group the dataset by name and assign to names

# %%
# you don't want to sum the Year column, so you delete it
del baby_names["Year"]

# group the data
names = baby_names.groupby("Name").sum()

# print the first 5 observations
names.head()

# print the size of the dataset
print(names.shape)

# sort it from the biggest value to the smallest one
names.sort_values("Count", ascending = 0).head()
# Out:
# (17632, 5)
#           Unnamed: 0          Id  \
# Name
# Jacob     1665680788  1665681356
# Emma      1629481684  1629482250
# Michael   1687520717  1687521295
# Ethan     1660807908  1660808475
# Isabella  1630131220  1630131786
#
#                                                      Gender  \
# Name
# Jacob     MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...
# Emma      FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF...
# Michael   MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMFF...
# Ethan     MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...
# Isabella  FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF...
#
#                                                       State   Count
# Name
# Jacob     AKAKAKAKAKAKAKAKAKAKAKALALALALALALALALALALALAR...  242874
# Emma      AKAKAKAKAKAKAKAKAKAKAKALALALALALALALALALALALAR...  214852
# Michael   AKAKAKAKAKAKAKAKAKAKAKALALALALALALALALALALALAR...  214405
# Ethan     AKAKAKAKAKAKAKAKAKAKAKALALALALALALALALALALALAR...  209277
# Isabella  AKAKAKAKAKAKAKAKAKAKAKALALALALALALALALALALALAR...  204798

# %%
names
# Out:
#          Unnamed: 0         Id  \
# Name
# Aaban       7733801    7733803
# Aadan       7158061    7158065
# Aadarsh     1728030    1728031
# Aaden     555052029  555052225
# Aadhav       709606     709607
# ...             ...        ...
# Zyra       17538998   17539005
# Zyrah       5487073    5487075
# Zyren       5074229    5074230
# Zyria      29787029   29787039
# Zyriah     34146196   34146205
#
#                                                     Gender  \
# Name
# Aaban                                                   MM
# Aadan                                                 MMMM
# Aadarsh                                                  M
# Aaden    MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...
# Aadhav                                                   M
# ...                                                    ...
# Zyra                                               FFFFFFF
# Zyrah                                                   FF
# Zyren                                                    M
# Zyria                                           FFFFFFFFFF
# Zyriah                                           FFFFFFFFF
#
#                                                      State  Count
# Name
# Aaban                                                 NYNY     12
# Aadan                                             CACACATX     23
# Aadarsh                                                 IL      5
# Aaden    ALALALALALALALARARARAZAZAZAZAZAZCACACACACACACA...   3426
# Aadhav                                                  CA      6
# ...                                                    ...    ...
# Zyra                                        CACACAFLTXTXTX     42
# Zyrah                                                 CATX     11
# Zyren                                                   TX      6
# Zyria                                 GAGAGALALALATXTXTXTX     59
# Zyriah                                  GAGALATXTXTXTXTXTX     58
#
# [17632 rows x 5 columns]

# %% [markdown]
# ### Step 8. How many different names exist in the dataset?

# %%
len(names)
# Out:
# 17632

# %% [markdown]
# ### Step 9. What is the name with most occurrences?

# %%
names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17632 entries, Aaban to Zyriah
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  17632 non-null  int64
#  1   Id          17632 non-null  int64
#  2   Gender      17632 non-null  object
#  3   State       17632 non-null  object
#  4   Count       17632 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 1.3+ MB

# %% [markdown]
# ### Step 10. How many different names have the least occurrences?

# %%
names[names.Count == names.Count.min()]
names
# Out:
#          Unnamed: 0         Id  \
# Name
# Aaban       7733801    7733803
# Aadan       7158061    7158065
# Aadarsh     1728030    1728031
# Aaden     555052029  555052225
# Aadhav       709606     709607
# ...             ...        ...
# Zyra       17538998   17539005
# Zyrah       5487073    5487075
# Zyren       5074229    5074230
# Zyria      29787029   29787039
# Zyriah     34146196   34146205
#
#                                                     Gender  \
# Name
# Aaban                                                   MM
# Aadan                                                 MMMM
# Aadarsh                                                  M
# Aaden    MMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMMM...
# Aadhav                                                   M
# ...                                                    ...
# Zyra                                               FFFFFFF
# Zyrah                                                   FF
# Zyren                                                    M
# Zyria                                           FFFFFFFFFF
# Zyriah                                           FFFFFFFFF
#
#                                                      State  Count
# Name
# Aaban                                                 NYNY     12
# Aadan                                             CACACATX     23
# Aadarsh                                                 IL      5
# Aaden    ALALALALALALALARARARAZAZAZAZAZAZCACACACACACACA...   3426
# Aadhav                                                  CA      6
# ...                                                    ...    ...
# Zyra                                        CACACAFLTXTXTX     42
# Zyrah                                                 CATX     11
# Zyren                                                   TX      6
# Zyria                                 GAGAGALALALATXTXTXTX     59
# Zyriah                                  GAGALATXTXTXTXTXTX     58
#
# [17632 rows x 5 columns]

# %% [markdown]
# ### Step 11. What is the median name occurrence?

# %%
names

# %% [markdown]
# ### Step 12. What is the standard deviation of names?

# %% [markdown]
# ### Step 13. Get a summary with the mean, min, max, std and quartiles.
